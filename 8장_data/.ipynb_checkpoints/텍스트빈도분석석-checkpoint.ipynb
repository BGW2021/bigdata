# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\programdata\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import pandas as pd
import glob
import re
from functools import reduce

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from collections import Counter

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
all_files = glob.glob('8장_data/myCabinetExcelData*.xls')

all_files
# Out:
# ['8장_data\\myCabinetExcelData (1).xls',
#  '8장_data\\myCabinetExcelData (2).xls',
#  '8장_data\\myCabinetExcelData (3).xls',
#  '8장_data\\myCabinetExcelData (4).xls',
#  '8장_data\\myCabinetExcelData (5).xls',
#  '8장_data\\myCabinetExcelData (6).xls',
#  '8장_data\\myCabinetExcelData (7).xls',
#  '8장_data\\myCabinetExcelData (8).xls',
#  '8장_data\\myCabinetExcelData (9).xls',
#  '8장_data\\myCabinetExcelData.xls']

# %%
all_files_data = []

for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)

all_files_data
# Out:
# [     Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Basanta-Val  P ,Audsley  N  C ,Wellings  A  J ...
#  2           NaN    3.0  Nunes  Rickey T  P ,Deshpande  Santosh L . "Co...
#  3           NaN    4.0  Baah-Peprah  Prince,Shneor  Rotem. "A trust-ba...
#  4           NaN    5.0  Raghavan  Krishnan,Jagannathan  Sarangapani,Sa...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Huang  Yiyi,Lin  Tao,Zhang  Guoqin,Zhu  Yonggu...
#  97          NaN   98.0  Mihály  Szabolcs,Remetey-Fülöpp  Gábor,Kristóf...
#  98          NaN   99.0  Kulmala  Markku,Lintunen  Anna,Ylivinkka  Ilon...
#  99          NaN  100.0   "Curating Big Data Made Simple: Perspectives ...
#  100         NaN  101.0  Zhang  Jinson,Huang  Mao Lin. "Data behaviours...
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Zhang  D ,He  T ,Lin  S ,Munir  S ,Stankovic  ...
#  2           NaN    3.0  Phinyomark  A ,Ibanez-Marcelo  E ,Petri  G . "...
#  3           NaN    4.0   "2017 Index IEEE Transactions on Big Data Vol...
#  4           NaN    5.0  Yaji  Sharath,Neelima  B . "Parallel computing...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Fernández  A ,Río  S ,Bawakid  A ,Herrera  F ....
#  97          NaN   98.0  Tosi  D . "Cell phone big data to compute mobi...
#  98          NaN   99.0  Cuzzocrea  A ,Sellis  T . "Semantics-Aware App...
#  99          NaN  100.0  Oatley  Giles C . "Themes in data mining, big ...
#  100         NaN  101.0  Shi  Y ,Shan  Z ,Li  J ,Fang  Y . "How China D...
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Zhang  D ,He  T ,Lin  S ,Munir  S ,Stankovic  ...
#  2           NaN    3.0  Phinyomark  A ,Ibanez-Marcelo  E ,Petri  G . "...
#  3           NaN    4.0   "2017 Index IEEE Transactions on Big Data Vol...
#  4           NaN    5.0  Yaji  Sharath,Neelima  B . "Parallel computing...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Fernández  A ,Río  S ,Bawakid  A ,Herrera  F ....
#  97          NaN   98.0  Tosi  D . "Cell phone big data to compute mobi...
#  98          NaN   99.0  Cuzzocrea  A ,Sellis  T . "Semantics-Aware App...
#  99          NaN  100.0  Oatley  Giles C . "Themes in data mining, big ...
#  100         NaN  101.0  Shi  Y ,Shan  Z ,Li  J ,Fang  Y . "How China D...
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Abbes  H ,Gargouri  F . "MongoDB-Based Modular...
#  2           NaN    3.0  Zhang  Y ,Nadarajah  S . "Flexible Heavy Taile...
#  3           NaN    4.0  Tian  Hua. "Research on the driving mechanism ...
#  4           NaN    5.0  Nalluri  Sravani,Sasikala  R . "An insight int...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Del Sol  Antonio,Thiesen  Hans J ,Imitola  Jai...
#  97          NaN   98.0  Zeng  T ,Zhang  W ,Yu  X ,Liu  X ,Li  M ,Chen ...
#  98          NaN   99.0  Kim  Jonghun,Jang  Heetae,Kim  Jong Tak,Pan  H...
#  99          NaN  100.0  Malik  K  R . "Big-data: transformation from h...
#  100         NaN  101.0  Yang  C ,Puthal  D ,Mohanty  S ,Kougianos  E ....
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Abbes  H ,Gargouri  F . "MongoDB-Based Modular...
#  2           NaN    3.0  Zhang  Y ,Nadarajah  S . "Flexible Heavy Taile...
#  3           NaN    4.0  Tian  Hua. "Research on the driving mechanism ...
#  4           NaN    5.0  Nalluri  Sravani,Sasikala  R . "An insight int...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Del Sol  Antonio,Thiesen  Hans J ,Imitola  Jai...
#  97          NaN   98.0  Zeng  T ,Zhang  W ,Yu  X ,Liu  X ,Li  M ,Chen ...
#  98          NaN   99.0  Kim  Jonghun,Jang  Heetae,Kim  Jong Tak,Pan  H...
#  99          NaN  100.0  Malik  K  R . "Big-data: transformation from h...
#  100         NaN  101.0  Yang  C ,Puthal  D ,Mohanty  S ,Kougianos  E ....
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Abbes  H ,Gargouri  F . "MongoDB-Based Modular...
#  2           NaN    3.0  Zhang  Y ,Nadarajah  S . "Flexible Heavy Taile...
#  3           NaN    4.0  Tian  Hua. "Research on the driving mechanism ...
#  4           NaN    5.0  Nalluri  Sravani,Sasikala  R . "An insight int...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Del Sol  Antonio,Thiesen  Hans J ,Imitola  Jai...
#  97          NaN   98.0  Zeng  T ,Zhang  W ,Yu  X ,Liu  X ,Li  M ,Chen ...
#  98          NaN   99.0  Kim  Jonghun,Jang  Heetae,Kim  Jong Tak,Pan  H...
#  99          NaN  100.0  Malik  K  R . "Big-data: transformation from h...
#  100         NaN  101.0  Yang  C ,Puthal  D ,Mohanty  S ,Kougianos  E ....
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Abbes  H ,Gargouri  F . "MongoDB-Based Modular...
#  2           NaN    3.0  Zhang  Y ,Nadarajah  S . "Flexible Heavy Taile...
#  3           NaN    4.0  Tian  Hua. "Research on the driving mechanism ...
#  4           NaN    5.0  Nalluri  Sravani,Sasikala  R . "An insight int...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Del Sol  Antonio,Thiesen  Hans J ,Imitola  Jai...
#  97          NaN   98.0  Zeng  T ,Zhang  W ,Yu  X ,Liu  X ,Li  M ,Chen ...
#  98          NaN   99.0  Kim  Jonghun,Jang  Heetae,Kim  Jong Tak,Pan  H...
#  99          NaN  100.0  Malik  K  R . "Big-data: transformation from h...
#  100         NaN  101.0  Yang  C ,Puthal  D ,Mohanty  S ,Kougianos  E ....
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Abbes  H ,Gargouri  F . "MongoDB-Based Modular...
#  2           NaN    3.0  Zhang  Y ,Nadarajah  S . "Flexible Heavy Taile...
#  3           NaN    4.0  Tian  Hua. "Research on the driving mechanism ...
#  4           NaN    5.0  Nalluri  Sravani,Sasikala  R . "An insight int...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Del Sol  Antonio,Thiesen  Hans J ,Imitola  Jai...
#  97          NaN   98.0  Zeng  T ,Zhang  W ,Yu  X ,Liu  X ,Li  M ,Chen ...
#  98          NaN   99.0  Kim  Jonghun,Jang  Heetae,Kim  Jong Tak,Pan  H...
#  99          NaN  100.0  Malik  K  R . "Big-data: transformation from h...
#  100         NaN  101.0  Yang  C ,Puthal  D ,Mohanty  S ,Kougianos  E ....
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Guo  Liang,Jin  Qianqian,Liu  Ying,Xia  Yuanyi...
#  2           NaN    3.0  Madsen  A  K ,Flyverbom  M ,Hilbert  M ,Rupper...
#  3           NaN    4.0  Qiu  Peihua. "Big Data? More Challenges!" Tech...
#  4           NaN    5.0  Kaisler  S ,Armour  F ,Espinosa  J A ,Money  W...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Alnaji  Loay A ,Eletter  Shorouq F ,Refae  Gha...
#  97          NaN   98.0  Calvert  Philip. "Big Data, Little Data: Schol...
#  98          NaN   99.0  Hudis  Clifford A . "Big data: Are large prosp...
#  99          NaN  100.0  Zhu  Jiangnan,Huang  Huang,Zhang  Dong. ""Big ...
#  100         NaN  101.0  O'Leary  D  E . "-BIG DATA-, THE -INTERNET OF ...
#
#  [101 rows x 3 columns],
#       Unnamed: 0     번호                                             참고문헌양식
#  0           NaN    NaN                                                NaN
#  1           NaN    2.0  Basanta-Val  P ,Audsley  N  C ,Wellings  A  J ...
#  2           NaN    3.0  Nunes  Rickey T  P ,Deshpande  Santosh L . "Co...
#  3           NaN    4.0  Baah-Peprah  Prince,Shneor  Rotem. "A trust-ba...
#  4           NaN    5.0  Raghavan  Krishnan,Jagannathan  Sarangapani,Sa...
#  ..          ...    ...                                                ...
#  96          NaN   97.0  Huang  Yiyi,Lin  Tao,Zhang  Guoqin,Zhu  Yonggu...
#  97          NaN   98.0  Mihály  Szabolcs,Remetey-Fülöpp  Gábor,Kristóf...
#  98          NaN   99.0  Kulmala  Markku,Lintunen  Anna,Ylivinkka  Ilon...
#  99          NaN  100.0   "Curating Big Data Made Simple: Perspectives ...
#  100         NaN  101.0  Zhang  Jinson,Huang  Mao Lin. "Data behaviours...
#
#  [101 rows x 3 columns]]

# %%
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)

all_files_data_concat
# Out:
#       Unnamed: 0     번호                                             참고문헌양식
# 0            NaN    NaN                                                NaN
# 1            NaN    2.0  Basanta-Val  P ,Audsley  N  C ,Wellings  A  J ...
# 2            NaN    3.0  Nunes  Rickey T  P ,Deshpande  Santosh L . "Co...
# 3            NaN    4.0  Baah-Peprah  Prince,Shneor  Rotem. "A trust-ba...
# 4            NaN    5.0  Raghavan  Krishnan,Jagannathan  Sarangapani,Sa...
# ...          ...    ...                                                ...
# 1005         NaN   97.0  Huang  Yiyi,Lin  Tao,Zhang  Guoqin,Zhu  Yonggu...
# 1006         NaN   98.0  Mihály  Szabolcs,Remetey-Fülöpp  Gábor,Kristóf...
# 1007         NaN   99.0  Kulmala  Markku,Lintunen  Anna,Ylivinkka  Ilon...
# 1008         NaN  100.0   "Curating Big Data Made Simple: Perspectives ...
# 1009         NaN  101.0  Zhang  Jinson,Huang  Mao Lin. "Data behaviours...
#
# [1010 rows x 3 columns]

# %%
all_files_data_concat.to_csv('8장_data/riss_bigdata.csv', encoding='utf-8', index = False)

# %%
all_title = all_files_data_concat['참고문헌양식']

all_title
# Out:
# 0                                                     NaN
# 1       Basanta-Val  P ,Audsley  N  C ,Wellings  A  J ...
# 2       Nunes  Rickey T  P ,Deshpande  Santosh L . "Co...
# 3       Baah-Peprah  Prince,Shneor  Rotem. "A trust-ba...
# 4       Raghavan  Krishnan,Jagannathan  Sarangapani,Sa...
#                               ...
# 1005    Huang  Yiyi,Lin  Tao,Zhang  Guoqin,Zhu  Yonggu...
# 1006    Mihály  Szabolcs,Remetey-Fülöpp  Gábor,Kristóf...
# 1007    Kulmala  Markku,Lintunen  Anna,Ylivinkka  Ilon...
# 1008     "Curating Big Data Made Simple: Perspectives ...
# 1009    Zhang  Jinson,Huang  Mao Lin. "Data behaviours...
# Name: 참고문헌양식, Length: 1010, dtype: object

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()

# %%
words = []  

for title in all_title:
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title))    
    EnWordsToken = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop]
    words.append(EnWordsTokenStopLemma)

# %%
print(words)
# Out:
# [['nan'], ['basanta', 'val', 'p', 'audsley', 'n', 'c', 'wellings', 'j', 'gray', 'fernandez', 'garcia', 'n', 'architecting', 'time', 'critical', 'big', 'data', 'system', 'ieee', 'transaction', 'big', 'data'], ['nunes', 'rickey', 'p', 'deshpande', 'santosh', 'l', 'computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow', 'international', 'journal', 'big', 'data', 'intelligence'], ['baah', 'peprah', 'prince', 'shneor', 'rotem', 'trust', 'based', 'crowdfunding', 'campaign', 'marketing', 'framework', 'theoretical', 'underpinnings', 'big', 'data', 'analytics', 'practice', 'international', 'journal', 'big', 'data', 'management'], ['raghavan', 'krishnan', 'jagannathan', 'sarangapani', 'samaranayake', 'v', 'game', 'theoretic', 'approach', 'addressing', 'domain', 'shift', 'big', 'data', 'ieee', 'transaction', 'big', 'data'], ['author', 'response', 'gong', 'comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making', 'big', 'data'], ['correction', 'predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better', 'junqu', 'de', 'fortuny', 'e', 'marten', 'provost', 'f', 'big', 'data', 'big', 'data'], ['data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making', 'big', 'data'], ['computational', 'propaganda', 'political', 'big', 'data', 'moving', 'toward', 'critical', 'research', 'agenda', 'big', 'data'], ['structural', 'consequence', 'big', 'data', 'driven', 'education', 'big', 'data'], ['basanta', 'val', 'p', 'nchez', 'fern', 'ndez', 'l', 'big', 'boe', 'fusing', 'spanish', 'official', 'gazette', 'big', 'data', 'technology', 'big', 'data'], ['qi', 'zhang', 'xuelong', 'liu', 'big', 'data', 'new', 'method', 'idea', 'geological', 'scientific', 'research', 'big', 'earth', 'data'], ['chakraborty', 'chinmay', 'khan', 'muhammad', 'khurram', 'ahmad', 'ishfaq', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data'], ['yu', 'yao', 'zhao', 'junhui', 'lenan', 'wu', 'multiple', 'target', 'tracking', 'big', 'data', 'based', 'measurement', 'extended', 'binary', 'phase', 'shift', 'keying', 'transceiver', 'big', 'data'], ['chakraborty', 'chinmay', 'khan', 'muhammad', 'khurram', 'ahmad', 'ishfaq', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data'], ['chakraborty', 'chinmay', 'khan', 'muhammad', 'khurram', 'ahmad', 'ishfaq', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data'], ['bring', 'big', 'data', 'beyond', 'hype', 'big', 'data'], ['cui', 'yaokui', 'chen', 'xi', 'gao', 'jinyu', 'yan', 'binyan', 'tang', 'guoqiang', 'hong', 'yang', 'global', 'water', 'cycle', 'remote', 'sensing', 'big', 'data', 'overview', 'challenge', 'opportunity', 'big', 'earth', 'data'], ['chakraborty', 'chinmay', 'khan', 'muhammad', 'khurram', 'ahmad', 'ishfaq', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data'], ['scalable', 'data', 'quality', 'big', 'data', 'pythia', 'framework', 'handling', 'missing', 'value', 'big', 'data'], ['castle', 'david', 'hebert', 'paul', 'n', 'clare', 'elizabeth', 'l', 'hogg', 'ian', 'tremblay', 'crystal', 'capturing', 'value', 'biosurveillance', 'big', 'data', 'natural', 'capital', 'accounting', 'big', 'earth', 'data'], ['assun', 'renato', 'pelechrinis', 'konstantinos', 'sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier', 'big', 'data'], ['assun', 'renato', 'pelechrinis', 'konstantinos', 'sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier', 'big', 'data'], ['xia', 'f', 'wang', 'w', 'bekele', 'liu', 'h', 'big', 'scholarly', 'data', 'survey', 'ieee', 'transaction', 'big', 'data'], ['chen', ' ...

# %%
words2 = list(reduce(lambda x, y: x+y, words))
print(words2)
# Out:
# ['nan', 'basanta', 'val', 'p', 'audsley', 'n', 'c', 'wellings', 'j', 'gray', 'fernandez', 'garcia', 'n', 'architecting', 'time', 'critical', 'big', 'data', 'system', 'ieee', 'transaction', 'big', 'data', 'nunes', 'rickey', 'p', 'deshpande', 'santosh', 'l', 'computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow', 'international', 'journal', 'big', 'data', 'intelligence', 'baah', 'peprah', 'prince', 'shneor', 'rotem', 'trust', 'based', 'crowdfunding', 'campaign', 'marketing', 'framework', 'theoretical', 'underpinnings', 'big', 'data', 'analytics', 'practice', 'international', 'journal', 'big', 'data', 'management', 'raghavan', 'krishnan', 'jagannathan', 'sarangapani', 'samaranayake', 'v', 'game', 'theoretic', 'approach', 'addressing', 'domain', 'shift', 'big', 'data', 'ieee', 'transaction', 'big', 'data', 'author', 'response', 'gong', 'comment', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making', 'big', 'data', 'correction', 'predictive', 'modeling', 'big', 'data', 'bigger', 'really', 'better', 'junqu', 'de', 'fortuny', 'e', 'marten', 'provost', 'f', 'big', 'data', 'big', 'data', 'data', 'science', 'relationship', 'big', 'data', 'data', 'driven', 'decision', 'making', 'big', 'data', 'computational', 'propaganda', 'political', 'big', 'data', 'moving', 'toward', 'critical', 'research', 'agenda', 'big', 'data', 'structural', 'consequence', 'big', 'data', 'driven', 'education', 'big', 'data', 'basanta', 'val', 'p', 'nchez', 'fern', 'ndez', 'l', 'big', 'boe', 'fusing', 'spanish', 'official', 'gazette', 'big', 'data', 'technology', 'big', 'data', 'qi', 'zhang', 'xuelong', 'liu', 'big', 'data', 'new', 'method', 'idea', 'geological', 'scientific', 'research', 'big', 'earth', 'data', 'chakraborty', 'chinmay', 'khan', 'muhammad', 'khurram', 'ahmad', 'ishfaq', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data', 'yu', 'yao', 'zhao', 'junhui', 'lenan', 'wu', 'multiple', 'target', 'tracking', 'big', 'data', 'based', 'measurement', 'extended', 'binary', 'phase', 'shift', 'keying', 'transceiver', 'big', 'data', 'chakraborty', 'chinmay', 'khan', 'muhammad', 'khurram', 'ahmad', 'ishfaq', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data', 'chakraborty', 'chinmay', 'khan', 'muhammad', 'khurram', 'ahmad', 'ishfaq', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data', 'bring', 'big', 'data', 'beyond', 'hype', 'big', 'data', 'cui', 'yaokui', 'chen', 'xi', 'gao', 'jinyu', 'yan', 'binyan', 'tang', 'guoqiang', 'hong', 'yang', 'global', 'water', 'cycle', 'remote', 'sensing', 'big', 'data', 'overview', 'challenge', 'opportunity', 'big', 'earth', 'data', 'chakraborty', 'chinmay', 'khan', 'muhammad', 'khurram', 'ahmad', 'ishfaq', 'call', 'special', 'issue', 'paper', 'big', 'data', 'driven', 'futuristic', 'fabric', 'system', 'societal', 'digital', 'transformation', 'big', 'data', 'scalable', 'data', 'quality', 'big', 'data', 'pythia', 'framework', 'handling', 'missing', 'value', 'big', 'data', 'castle', 'david', 'hebert', 'paul', 'n', 'clare', 'elizabeth', 'l', 'hogg', 'ian', 'tremblay', 'crystal', 'capturing', 'value', 'biosurveillance', 'big', 'data', 'natural', 'capital', 'accounting', 'big', 'earth', 'data', 'assun', 'renato', 'pelechrinis', 'konstantinos', 'sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier', 'big', 'data', 'assun', 'renato', 'pelechrinis', 'konstantinos', 'sport', 'analytics', 'era', 'big', 'data', 'moving', 'toward', 'next', 'frontier', 'big', 'data', 'xia', 'f', 'wang', 'w', 'bekele', 'liu', 'h', 'big', 'scholarly', 'data', 'survey', 'ieee', 'transaction', 'big', 'data', 'chen', 'bin', 'xu', 'bing', 'gong', 'peng', 'mapping', 'e ...

# %%
count = Counter(words2)

count
# Out:
# Counter({'data': 1951,
#          'big': 1321,
#          'knowledge': 229,
#          'engineering': 219,
#          'ieee': 218,
#          'journal': 208,
#          'transaction': 207,
#          'analytics': 189,
#          'international': 187,
#          'analysis': 156,
#          'mining': 149,
#          'system': 138,
#          'management': 128,
#          'science': 126,
#          'earth': 112,
#          'j': 108,
#          'based': 101,
#          'c': 99,
#          'chen': 97,
#          'n': 96,
#          'li': 91,
#          'zhang': 82,
#          'k': 80,
#          'l': 78,
#          'wang': 74,
#          'approach': 71,
#          'yang': 71,
#          'using': 68,
#          'application': 62,
#          'driven': 61,
#          'learning': 60,
#          'r': 60,
#          'h': 58,
#          'model': 57,
#          'issue': 56,
#          'industrial': 55,
#          'p': 54,
#          'intelligence': 54,
#          'f': 52,
#          'discovery': 52,
#          'algorithm': 50,
#          'framework': 47,
#          'distributed': 46,
#          'wire': 46,
#          'special': 45,
#          'technology': 44,
#          'paper': 42,
#          'cloud': 42,
#          'processing': 42,
#          'research': 41,
#          'e': 39,
#          'huang': 39,
#          'machine': 39,
#          'guo': 38,
#          'perspective': 38,
#          'warehousing': 37,
#          'call': 36,
#          'scalable': 36,
#          'g': 36,
#          'sustainable': 36,
#          'computational': 35,
#          'online': 35,
#          'wu': 34,
#          'efficient': 34,
#          'kim': 34,
#          'time': 33,
#          'computing': 33,
#          'w': 32,
#          'information': 32,
#          'v': 31,
#          'liu': 31,
#          'challenge': 31,
#          'survey': 31,
#          'xu': 31,
#          'health': 31,
#          'smart': 31,
#          'platform': 30,
#          'technique': 30,
#          'yu': 29,
#          'review': 29,
#          'network': 28,
#          'statistic': 28,
#          'business': 27,
#          'statistical': 27,
#          'x': 27,
#          'method': 26,
#          'cheng': 25,
#          'communication': 25,
#          'mapreduce': 25,
#          'new': 24,
#          'zhao': 23,
#          'gao': 23,
#          'era': 23,
#          'strategy': 23,
#          'digital': 22,
#          'fusion': 22,
#          'detection': 22,
#          'wireless': 22,
#          'warehouse': 22,
#          'tang': 21,
#          'opportunity': 21,
#          'privacy': 21,
#          'computer': 21,
#          'zhu': 20,
#          'development': 20,
#          'goal': 20,
#          'optimization': 20,
#          'kumar': 20,
#          'sensing': 19,
#          'support': 19,
#          'ming': 19,
#          'risk': 19,
#          'assessment': 19,
#          'q': 19,
#          'clustering': 19,
#          'market': 19,
#          'b': 19,
#          'z': 19,
#          'cell': 19,
#          'modeling': 18,
#          'muhammad': 18,
#          'measurement': 18,
#          'medium': 18,
#          'process': 18,
#          'security': 18,
#          'spatial': 18,
#          'service': 18,
#          'na': 18,
#          'zhou': 18,
#          'industry': 18,
#          'image': 18,
#          'query': 17,
#          'high': 17,
#          'modelling': 17,
#          'ho': 17,
#          'wei': 17,
#          'xie': 17,
#          'jia': 17,
#          'semantics': 17,
#          'evaluating': 17,
#          'insight': 17,
#          'via': 17,
#          'yuan': 17,
#          'song': 17,
#          'proceeding': 17,
#          'peng': 16,
#          'innovation': 16,
#          'intelligent': 16,
#          'multi': 16,
#          'financial': 16,
#          'sensor': 16,
#          'public': 16,
#          'annals': 16,
#          'design': 16,
#          'dimension': 16,
#          'gong': 15,
#          'transformation': 15,
#          'use': 15,
#          'thomas': 15,
#          'exploring': 15,
#          'scale': 15,
#          'feng': 15,
#          'jianzhong': 15,
#          'lan': 15,
#          'incremental': 15,
#          'lei': 15,
#          'approximation': 15,
#          'khan': 14,
#          'phase': 14,
#          'yan': 14,
#          'artificial': 14,
#          'small': 14,
#          'ge': 14,
#          'sheng': 14,
#          'healthcare': 14,
#          'ai': 14,
#          'sharing': 14,
#          'towards': 14,
#          'zeng': 14,
#          'zheng': 14,
#          'graph': 14,
#          'storage': 14,
#          'bayesian': 14,
#          'integration': 14,
#          'bioinformatics': 13,
#          'scientific': 13,
#          'guest': 13,
#          'editorial': 13,
#          'deep': 13,
#          'disaster': 13,
#          'internet': 13,
#          'city': 13,
#          'evidence': 13,
#          'hu': 13,
#          'fang': 13,
#          'environment': 13,
#          'rule': 13,
#          'series': 13,
#          'society': 13,
#          'production': 13,
#          'generation': 13,
#          'theoretical': 12,
#          'de': 12,
#          'fern': 12,
#          'ndez': 12,
#          'qi': 12,
#          'global': 12,
#          'overview': 12,
#          'next': 12,
#          'understanding': 12,
#          'classification': 12,
#          'thing': 12,
#          'community': 12,
#          'generalized': 12,
#          'sampling': 12,
#          'transforming': 12,
#          'nearest': 12,
#          'error': 12,
#          'distribution': 12,
#          'advance': 12,
#          'tool': 12,
#          'reduction': 12,
#          'hao': 12,
#          'gang': 12,
#          'compression': 12,
#          'yi': 12,
#          'uncertainty': 12,
#          'jie': 12,
#          'yao': 11,
#          'hong': 11,
#          'study': 11,
#          'han': 11,
#          'capability': 11,
#          'mohammad': 11,
#          'selection': 11,
#          'parallel': 11,
#          'large': 11,
#          'chain': 11,
#          'finance': 11,
#          'social': 11,
#          'future': 11,
#          'zhong': 11,
#          'analyzing': 11,
#          'chao': 11,
#          'lu': 11,
#          'relation': 11,
#          'non': 11,
#          'real': 11,
#          'nan': 10,
#          'marketing': 10,
#          'toward': 10,
#          'ahmad': 10,
#          'role': 10,
#          'search': 10,
#          'competitive': 10,
#          'huadong': 10,
#          'center': 10,
#          'architecture': 10,
#          'robert': 10,
#          'chang': 10,
#          'fuzzy': 10,
#          'grid': 10,
#          'china': 10,
#          'lee': 10,
#          'liang': 10,
#          'cuzzocrea': 10,
#          'problem': 10,
#          'building': 10,
#          'tian': 10,
#          'electrophysiology': 10,
#          'construction': 10,
#          'shah': 10,
#          'enhanced': 10,
#          'stream': 10,
#          'haiying': 10,
#          'methodology': 10,
#          'wen': 10,
#          'hongyan': 10,
#          'device': 10,
#          'barrier': 10,
#          'regional': 10,
#          'twitter': 10,
#          'collection': 10,
#          'shimin': 10,
#          'store': 10,
#          'pan': 10,
#          'sutedi': 10,
#          'pre': 10,
#          'matrix': 10,
#          'join': 10,
#          'kernel': 10,
#          'gaussian': 10,
#          'access': 10,
#          'car': 10,
#          'der': 10,
#          'wirtschaftsinformatik': 10,
#          'und': 10,
#          'spie': 10,
#          'optical': 10,
#          'scheduling': 10,
#          'vision': 10,
#          'shukla': 10,
#          'toxicology': 10,
#          'course': 10,
#          'stem': 10,
#          'santosh': 9,
#          'correction': 9,
#          'education': 9,
#          'chakraborty': 9,
#          'multiple': 9,
#          'quality': 9,
#          'david': 9,
#          'context': 9,
#          'impact': 9,
#          'feature': 9,
#          'balamurugan': 9,
#          'infrastructure': 9,
#          'performance': 9,
#          'lizhe': 9,
#          'bo': 9,
#          'pattern': 9,
#          'green': 9,
#          'pipeline': 9,
#          'classifier': 9,
#          'yong': 9,
#          'xinyu': 9,
#          'enterprise': 9,
#          'transportation': 9,
#          'herrera': 9,
#          'supply': 9,
#          'control': 9,
#          'raymond': 9,
#          'conference': 9,
#          'del': 9,
#          'world': 9,
#          'practice': 8,
#          'chinmay': 8,
#          'khurram': 8,
#          'ishfaq': 8,
#          'futuristic': 8,
#          'fabric': 8,
#          'societal': 8,
#          'elizabeth': 8,
#          'ke': 8,
#          'solution': 8,
#          'clinical': 8,
#          'mohd': 8,
#          'map': 8,
#          'sparse': 8,
#          'lin': 8,
#          'annual': 8,
#          'view': 8,
#          'shi': 8,
#          'matthew': 8,
#          'brian': 8,
#          'behavior': 8,
#          'hadoop': 8,
#          'silva': 8,
#          'rez': 8,
#          'implementation': 8,
#          'dynamic': 8,
#          'implication': 8,
#          'law': 8,
#          'nunes': 7,
#          'rickey': 7,
#          'deshpande': 7,
#          'computation': 7,
#          'workflow': 7,
#          'decision': 7,
#          'predictive': 7,
#          'moving': 7,
#          'handling': 7,
#          'natural': 7,
#          'capital': 7,
#          'bin': 7,
#          'bing': 7,
#          'ju': 7,
#          'bao': 7,
#          'mean': 7,
#          'zhi': 7,
#          'pei': 7,
#          'jason': 7,
#          'antonio': 7,
#          'singh': 7,
#          'manoj': 7,
#          'set': 7,
#          'bibliometric': 7,
#          'verma': 7,
#          'optimal': 7,
#          'mr': 7,
#          'resource': 7,
#          'localization': 7,
#          'firm': 7,
#          'perception': 7,
#          'make': 7,
#          'daniel': 7,
#          'iot': 7,
#          'theory': 7,
#          'hossein': 7,
#          'order': 7,
#          'stakeholder': 7,
#          'ecosystem': 7,
#          'simple': 7,
#          'demand': 7,
#          'preserving': 7,
#          'cong': 7,
#          'luo': 7,
#          'similarity': 7,
#          'park': 7,
#          'fraud': 7,
#          'report': 7,
#          'extracting': 7,
#          'estimation': 7,
#          'heterogeneous': 7,
#          'xing': 7,
#          'joseph': 7,
#          'comprehensive': 7,
#          'fei': 7,
#          'xuan': 7,
#          'simulation': 7,
#          'ontology': 7,
#          'semantic': 7,
#          'web': 7,
#          'majid': 7,
#          'supervised': 7,
#          'monitoring': 7,
#          'long': 7,
#          'blood': 7,
#          'donation': 7,
#          'garc': 7,
#          'francisco': 7,
#          'neighbor': 7,
#          'novel': 7,
#          'ding': 7,
#          'yichuan': 7,
#          'taiwen': 7,
#          'regression': 7,
#          'divide': 7,
#          'evolving': 7,
#          'marco': 7,
#          'daisuke': 7,
#          'japanese': 7,
#          'enabled': 7,
#          'allocation': 7,
#          'content': 7,
#          'spark': 7,
#          'experimental': 7,
#          'andreas': 7,
#          'pez': 7,
#          'xindong': 7,
#          'strang': 7,
#          'memory': 7,
#          'whang': 7,
#          'steven': 7,
#          'euijong': 7,
#          'qinghua': 7,
#          'compute': 7,
#          'sellis': 7,
#          'manufacturing': 7,
#          'hot': 7,
#          'factor': 7,
#          'lecture': 7,
#          'note': 7,
#          'informatics': 7,
#          'trading': 7,
#          'personal': 7,
#          'extended': 6,
#          'accounting': 6,
#          'frontier': 6,
#          'scholarly': 6,
#          'urban': 6,
#          'geospatial': 6,
#          'visual': 6,
#          'sebe': 6,
#          'aggarwal': 6,
#          'hacker': 6,
#          'accurate': 6,
#          'victor': 6,
#          'qian': 6,
#          'reference': 6,
#          'agricultural': 6,
#          'abd': 6,
#          'nobanee': 6,
#          'haitham': 6,
#          'paolo': 6,
#          'utilization': 6,
#          'christopher': 6,
#          'sector': 6,
#          'stephen': 6,
#          'mumtaz': 6,
#          'programming': 6,
#          'ye': 6,
#          'sun': 6,
#          'ben': 6,
#          'yue': 6,
#          'michael': 6,
#          'jos': 6,
#          'economy': 6,
#          'donghua': 6,
#          'mauro': 6,
#          'product': 6,
#          'holistic': 6,
#          'william': 6,
#          'medical': 6,
#          'tsai': 6,
#          'sachin': 6,
#          'networking': 6,
#          'arun': 6,
#          'automatic': 6,
#          'oriented': 6,
#          'contextual': 6,
#          'ting': 6,
#          'identification': 6,
#          'acm': 6,
#          'ray': 6,
#          'karim': 6,
#          'van': 6,
#          'planning': 6,
#          'energy': 6,
#          'prevention': 6,
#          'today': 6,
#          'edge': 6,
#          'drug': 6,
#          'multimedia': 6,
#          'promise': 6,
#          'magazine': 6,
#          'critical': 5,
#          'relationship': 5,
#          'bigger': 5,
#          'political': 5,
#          'value': 5,
#          'mapping': 5,
#          'prediction': 5,
#          'biomedical': 5,
#          'xiao': 5,
#          'el': 5,
#          'al': 5,
#          'qu': 5,
#          'spatio': 5,
#          'temporal': 5,
#          'corporate': 5,
#          'first': 5,
#          'salvador': 5,
#          'investigation': 5,
#          'abbe': 5,
#          'gargouri': 5,
#          'mongodb': 5,
#          'modular': 5,
#          'nadarajah': 5,
#          'flexible': 5,
#          'heavy': 5,
#          'tailed': 5,
#          'hua': 5,
#          'driving': 5,
#          'mechanism': 5,
#          'startup': 5,
#          'nalluri': 5,
#          'sravani': 5,
#          'sasikala': 5,
#          'xixian': 5,
#          'jinbao': 5,
#          'skyline': 5,
#          'enrico': 5,
#          'barbierato': 5,
#          'gribaudo': 5,
#          'iacono': 5,
#          'effect': 5,
#          'woo': 5,
#          'jongwook': 5,
#          'mishra': 5,
#          'monika': 5,
#          'predicting': 5,
#          'rating': 5,
#          'amazon': 5,
#          'joshiara': 5,
#          'hetal': 5,
#          'thaker': 5,
#          'chirag': 5,
#          'sanjay': 5,
#          'choksi': 5,
#          'darshan': 5,
#          'straggler': 5,
#          'rescheduling': 5,
#          'slow': 5,
#          'running': 5,
#          'task': 5,
#          'lfcso': 5,
#          'lvq': 5,
#          'pso': 5,
#          'thangaraj': 5,
#          'consensus': 5,
#          'lime': 5,
#          'rado': 5,
#          'ratsimbazafyboussaid': 5,
#          'omar': 5,
#          'decisional': 5,
#          'ardakani': 5,
#          'omid': 5,
#          'asadi': 5,
#          'ebrahimi': 5,
#          'nader': 5,
#          'soofi': 5,
#          'ehsan': 5,
#          'plot': 5,
#          'distinguishing': 5,
#          'fegaras': 5,
#          'haixiang': 5,
#          'subdata': 5,
#          'ok': 5,
#          'ran': 5,
#          'jeong': 5,
#          'chulyun': 5,
#          'neha': 5,
#          'jatinder': 5,
#          'retail': 5,
#          'apriori': 5,
#          'joochul': 5,
#          'schifano': 5,
#          'updating': 5,
#          'correct': 5,
#          'roshan': 5,
#          'mak': 5,
#          'simon': 5,
#          'analysing': 5,
#          'repeat': 5,
#          'francesco': 5,
#          'di': 5,
#          'tria': 5,
#          'ezio': 5,
#          'lefons': 5,
#          'filippo': 5,
#          'tangorra': 5,
#          'tung': 5,
#          'barthur': 5,
#          'ashrith': 5,
#          'bower': 5,
#          'yuying': 5,
#          'gerth': 5,
#          'john': 5,
#          'cleveland': 5,
#          'recombine': 5,
#          'project': 5,
#          'complexity': 5,
#          'lucheng': 5,
#          'chu': 5,
#          'dianhui': 5,
#          'responding': 5,
#          'turbulence': 5,
#          'mass': 5,
#          'customization': 5,
#          'kenneth': 5,
#          'shuyang': 5,
#          'embedding': 5,
#          'factory': 5,
#          'sap': 5,
#          'consultant': 5,
#          'tseng': 5,
#          'lang': 5,
#          'bui': 5,
#          'tat': 5,
#          'dat': 5,
#          'lim': 5,
#          'tan': 5,
#          'comparing': 5,
#          'advancing': 5,
#          'terzi': 5,
#          'duygu': 5,
#          'sinan': 5,
#          'sa': 5,
#          'ro': 5,
#          'eref': 5,
#          'hakan': 5,
#          'telecom': 5,
#          'hajiheydari': 5,
#          'nastaran': 5,
#          'delgosha': 5,
#          'soltani': 5,
#          'olya': 5,
#          'path': 5,
#          'success': 5,
#          'banking': 5,
#          'integrated': 5,
#          'kirubakaran': 5,
#          'anusuya': 5,
#          'aramudhan': 5,
#          'watchdog': 5,
#          'name': 5,
#          'matching': 5,
#          'raut': 5,
#          'rakesh': 5,
#          'narwane': 5,
#          'vaibhav': 5,
#          'mangla': 5,
#          'yadav': 5,
#          'vinay': 5,
#          'surendra': 5,
#          'narkhede': 5,
#          'balkrishna': 5,
#          'eknath': 5,
#          'luthra': 5,
#          'sunil': 5,
#          'unlocking': 5,
#          'causal': 5,
#          'finogeev': 5,
#          'alexey': 5,
#          'gamidullaeva': 5,
#          'leyla': 5,
#          'vasin': 5,
#          'sergey': 5,
#          'hyper': 5,
#          'convergent': 5,
#          'andr': 5,
#          'marie': 5,
#          'zamira': 5,
#          'burgos': 5,
#          'word': 5,
#          'mouth': 5,
#          'csr': 5,
#          'roh': 5,
#          'yuji': 5,
#          'heo': 5,
#          'geon': 5,
#          'velev': 5,
#          'dimiter': 5,
#          'zlateva': 5,
#          'plamena': 5,
#          'gupta': 5,
#          'preeti': 5,
#          'sharma': 5,
#          'jindal': 5,
#          'rajni': 5,
#          'samaraweera': 5,
#          'dumindu': 5,
#          'morris': 5,
#          'database': 5,
#          'sautot': 5,
#          'lucile': 5,
#          'bimonte': 5,
#          'sandro': 5,
#          'journaux': 5,
#          'ludovic': 5,
#          'semi': 5,
#          'fact': 5,
#          'ku': 5,
#          'broadcasting': 5,
#          'yanfeng': 5,
#          'qiang': 5,
#          'jianguo': 5,
#          'dingding': 5,
#          'bias': 5,
#          'sample': 5,
#          'kafeza': 5,
#          'eleanna': 5,
#          'kanavos': 5,
#          'makris': 5,
#          'christos': 5,
#          'pispirigos': 5,
#          'georgios': 5,
#          'vikatos': 5,
#          'pantelis': 5,
#          'pcce': 5,
#          'personality': 5,
#          'communicative': 5,
#          'extraction': 5,
#          'xiangmin': 5,
#          'xiaochun': 5,
#          'timos': 5,
#          'recommendation': 5,
#          'stock': 5,
#          'direction': 5,
#          'va': 5,
#          'virtual': 5,
#          'approximate': 5,
#          'supporting': 5,
#          'repetitive': 5,
#          'genome': 5,
#          'sequence': 5,
#          'shanjiang': 5,
#          'bingsheng': 5,
#          'ce': 5,
#          'yusen': 5,
#          'kun': 5,
#          'huan': 5,
#          'bit': 5,
#          'aggregation': 5,
#          'kehao': 5,
#          'linke': 5,
#          'bolong': 5,
#          'federated': 5,
#          'recommender': 5,
#          'godwin': 5,
#          'suspicious': 5,
#          'tax': 5,
#          'evasion': 5,
#          'group': 5,
#          'dutta': 5,
#          'palash': 5,
#          'measure': 5,
#          'conflict': 5,
#          'dempster': 5,
#          'shafer': 5,
#          'ordonez': 5,
#          'cabrera': 5,
#          'gamma': 5,
#          'summarize': 5,
#          'dense': 5,
#          'chihao': 5,
#          'shihua': 5,
#          'decomposition': 5,
#          'step': 5,
#          'nonlinear': 5,
#          'rochas': 5,
#          'beze': 5,
#          'huet': 5,
#          'magoules': 5,
#          'neighbour': 5,
#          'yongquan': 5,
#          'runze': 5,
#          'feasibility': 5,
#          'richard': 5,
#          'yubin': 5,
#          'haery': 5,
#          'accumulative': 5,
#          'dimensional': 5,
#          'nuno': 5,
#          'carvalho': 5,
#          'takahide': 5,
#          'matsutsuka': 5,
#          'linked': 5,
#          'fangzhou': 5,
#          'mingxuan': 5,
#          'xike': 5,
#          'shenglin': 5,
#          'rao': 5,
#          'weixiong': 5,
#          'sequential': 5,
#          'telco': 5,
#          'alfredo': 5,
#          'grasso': 5,
#          'giorgio': 5,
#          'mario': 5,
#          'nolich': 5,
#          'massimiliano': 5,
#          'effective': 5,
#          'chunk': 5,
#          'chi': 5,
#          'xianghua': 5,
#          'ramamohanarao': 5,
#          'kotagiri': 5,
#          'jinjun': 5,
#          'source': 5,
#          'recursive': 5,
#          'fast': 5,
#          'recovery': 5,
#          'siyao': 5,
#          'cai': 5,
#          'zhipeng': 5,
#          'dataset': 5,
#          'sensory': 5,
#          'yicheng': 5,
#          'jae': 5,
#          'kwang': 5,
#          'cho': 5,
#          'fractional': 5,
#          'deck': 5,
#          'imputation': 5,
#          'variance': 5,
#          'incomplete': 5,
#          'curing': 5,
#          'canonical': 5,
#          'correlation': 5,
#          'multiview': 5,
#          'xiaofeng': 5,
#          'jiong': 5,
#          'minyi': 5,
#          'skia': 5,
#          'textual': 5,
#          'yixiang': 5,
#          'reynold': 5,
#          'wenbin': 5,
#          'maniu': 5,
#          'silviu': 5,
#          'trajectory': 5,
#          'drignei': 5,
#          'dorin': 5,
#          'emulated': 5,
#          'zilber': 5,
#          'katzfuss': 5,
#          'matthias': 5,
#          'vecchia': 5,
#          'laplace': 5,
#          'dan': 5,
#          'yunbo': 5,
#          'xiaoli': 5,
#          'factorization': 5,
#          'blind': 5,
#          'yandong': 5,
#          'guangxi': 5,
#          'yangxu': 5,
#          'juanjuan': 5,
#          'peiyi': 5,
#          'advantage': 5,
#          'hailing': 5,
#          'costa': 5,
#          'madeira': 5,
#          'distrubted': 5,
#          'dws': 5,
#          'workshop': 5,
#          'olap': 5,
#          'mullock': 5,
#          'eu': 5,
#          'face': 5,
#          'shake': 5,
#          'direct': 5,
#          'xuesong': 5,
#          'mingzhao': 5,
#          'stack': 5,
#          'seismic': 5,
#          'inversion': 5,
#          'agneeswaran': 5,
#          'hecker': 5,
#          'gesch': 5,
#          'ftsmodelle': 5,
#          'die': 5,
#          'drei': 5,
#          'seiten': 5,
#          'medaille': 5,
#          'popov': 5,
#          'bold': 5,
#          'chai': 5,
#          'forde': 5,
#          'hyslip': 5,
#          'kashani': 5,
#          'hsu': 5,
#          'railway': 5,
#          'track': 5,
#          'maintenance': 5,
#          'efficiency': 5,
#          'neural': 5,
#          'material': 5,
#          'contrast': 5,
#          'imaging': 5,
#          'transfer': 5,
#          'maximizing': 5,
#          'throughput': 5,
#          'zargham': 5,
#          'screening': 5,
#          'bregman': 5,
#          'divergence': 5,
#          'recognition': 5,
#          'xinkai': 5,
#          'recruitment': 5,
#          'program': 5,
#          'franz': 5,
#          'anwendungsf': 5,
#          'lle': 5,
#          'methodisch': 5,
#          'erarbeiten': 5,
#          'kanoun': 5,
#          'schaar': 5,
#          'mihaela': 5,
#          'streaming': 5,
#          'concept': 5,
#          'drift': 5,
#          'date': 5,
#          'manish': 5,
#          'tiwari': 5,
#          'incorporating': 5,
#          'smallholder': 5,
#          'palm': 5,
#          'oil': 5,
#          'yamagata': 5,
#          'yoshiki': 5,
#          'murakami': 5,
#          'yihan': 5,
#          'perry': 5,
#          'yoshida': 5,
#          'takahiro': 5,
#          'binder': 5,
#          'carbon': 5,
#          'emission': 5,
#          'walkable': 5,
#          'procedia': 5,
#          'jalali': 5,
#          'arash': 5,
#          'rahden': 5,
#          'douglas': 5,
#          'heintz': 5,
#          'joerg': 5,
#          'filla': 5,
#          'greg': 5,
#          'dinovi': 5,
#          'mensah': 5,
#          'edward': 5,
#          'smarter': 5,
#          'sphps': 5,
#          'amia': 5,
#          'symposium': 5,
#          'luechtefeld': 5,
#          'rowlands': 5,
#          ...})

# %%
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" %(tag, counts))
# Out:
# data : 1951
# big : 1321
# knowledge : 229
# engineering : 219
# ieee : 218
# journal : 208
# transaction : 207
# analytics : 189
# international : 187
# analysis : 156
# mining : 149
# system : 138
# management : 128
# science : 126
# earth : 112
# based : 101
# chen : 97
# li : 91
# zhang : 82
# wang : 74
# approach : 71
# yang : 71
# using : 68
# application : 62
# driven : 61
# learning : 60
# model : 57
# issue : 56
# industrial : 55
# intelligence : 54
# discovery : 52
# algorithm : 50
# framework : 47
# distributed : 46
# wire : 46
# special : 45
# technology : 44
# paper : 42
# cloud : 42
# processing : 42
# research : 41

# %%
del word_count['big']
del word_count['data']

# %%
plt.figure(figsize=(12,5))
plt.xlabel("word")
plt.ylabel("count")
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='vertical')


plt.show()

# %%
all_files_data_concat['doc_count'] = 0
summary_year = all_files_data_concat.groupby('출판일', as_index=False)['doc_count'].count()
summary_year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 all_files_data_concat['doc_count'] = 0
# ----> 2 summary_year = all_files_data_concat.groupby('출판일', as_index=False)['doc_count'].count()
#       3 summary_year
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: '출판일'

# %%
stopwords=set(STOPWORDS)
wc=WordCloud(background_color='ivory', stopwords=stopwords, width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file("8장_data/riss_bigdata_wordCloud.jpg")

# %%
word_count['big'] = word_count_backup['big']
word_count['data'] = word_count_backup['data']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 word_count['big'] = word_count_backup['big']
#       2 word_count['data'] = word_count_backup['data']
#
# NameError: name 'word_count_backup' is not defined

# %%
all_files_data = []

for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)

all_files_data[0]
# Out:
#      Unnamed: 0     번호                                             참고문헌양식
# 0           NaN    NaN                                                NaN
# 1           NaN    2.0  Basanta-Val  P ,Audsley  N  C ,Wellings  A  J ...
# 2           NaN    3.0  Nunes  Rickey T  P ,Deshpande  Santosh L . "Co...
# 3           NaN    4.0  Baah-Peprah  Prince,Shneor  Rotem. "A trust-ba...
# 4           NaN    5.0  Raghavan  Krishnan,Jagannathan  Sarangapani,Sa...
# ..          ...    ...                                                ...
# 96          NaN   97.0  Huang  Yiyi,Lin  Tao,Zhang  Guoqin,Zhu  Yonggu...
# 97          NaN   98.0  Mihály  Szabolcs,Remetey-Fülöpp  Gábor,Kristóf...
# 98          NaN   99.0  Kulmala  Markku,Lintunen  Anna,Ylivinkka  Ilon...
# 99          NaN  100.0   "Curating Big Data Made Simple: Perspectives ...
# 100         NaN  101.0  Zhang  Jinson,Huang  Mao Lin. "Data behaviours...
#
# [101 rows x 3 columns]

# %%
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)

all_files_data_concat
# Out:
#       Unnamed: 0     번호                                             참고문헌양식
# 0            NaN    NaN                                                NaN
# 1            NaN    2.0  Basanta-Val  P ,Audsley  N  C ,Wellings  A  J ...
# 2            NaN    3.0  Nunes  Rickey T  P ,Deshpande  Santosh L . "Co...
# 3            NaN    4.0  Baah-Peprah  Prince,Shneor  Rotem. "A trust-ba...
# 4            NaN    5.0  Raghavan  Krishnan,Jagannathan  Sarangapani,Sa...
# ...          ...    ...                                                ...
# 1005         NaN   97.0  Huang  Yiyi,Lin  Tao,Zhang  Guoqin,Zhu  Yonggu...
# 1006         NaN   98.0  Mihály  Szabolcs,Remetey-Fülöpp  Gábor,Kristóf...
# 1007         NaN   99.0  Kulmala  Markku,Lintunen  Anna,Ylivinkka  Ilon...
# 1008         NaN  100.0   "Curating Big Data Made Simple: Perspectives ...
# 1009         NaN  101.0  Zhang  Jinson,Huang  Mao Lin. "Data behaviours...
#
# [1010 rows x 3 columns]

# %%
all_files_data_concat.to_csv('8장_data/riss_bigdata.csv', encoding='utf-8', index = False)

# %%
plt.figure(figsize=(12,5))
plt.xlabel("word")
plt.ylabel("count")
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='vertical')


plt.show()

# %%
stopwords=set(STOPWORDS)
wc=WordCloud(background_color='ivory', stopwords=stopwords, width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
all_title = all_files_data_concat['참고문헌양식
']

all_title
# Out:
# 0                                                     NaN
# 1       Basanta-Val  P ,Audsley  N  C ,Wellings  A  J ...
# 2       Nunes  Rickey T  P ,Deshpande  Santosh L . "Co...
# 3       Baah-Peprah  Prince,Shneor  Rotem. "A trust-ba...
# 4       Raghavan  Krishnan,Jagannathan  Sarangapani,Sa...
#                               ...
# 1005    Huang  Yiyi,Lin  Tao,Zhang  Guoqin,Zhu  Yonggu...
# 1006    Mihály  Szabolcs,Remetey-Fülöpp  Gábor,Kristóf...
# 1007    Kulmala  Markku,Lintunen  Anna,Ylivinkka  Ilon...
# 1008     "Curating Big Data Made Simple: Perspectives ...
# 1009    Zhang  Jinson,Huang  Mao Lin. "Data behaviours...
# Name: 참고문헌양식, Length: 1010, dtype: object

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 stopWords = set(stopwords.words("english"))
#       2 lemma = WordNetLemmatizer()
#
# AttributeError: 'set' object has no attribute 'words'

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 stopWords = set(stopwords.words("english"))
#       2 lemma = WordNetLemmatizer()
#
# AttributeError: 'set' object has no attribute 'words'

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('stopwords')
nltk.download('wordnet')

stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1951
# big : 1321
# knowledge : 229
# engineering : 219
# ieee : 218
# journal : 208
# transaction : 207
# analytics : 189
# international : 187
# analysis : 156
# mining : 149
# system : 138
# management : 128
# science : 126
# earth : 112
# based : 101
# chen : 97
# li : 91
# zhang : 82
# wang : 74
# approach : 71
# yang : 71
# using : 68
# application : 62
# driven : 61
# learning : 60
# model : 57
# issue : 56
# industrial : 55
# intelligence : 54
# discovery : 52
# algorithm : 50
# framework : 47
# distributed : 46
# wire : 46
# special : 45
# technology : 44
# paper : 42
# cloud : 42
# processing : 42
# research : 41

# %%
plt.figure(figsize=(12,5))
plt.xlabel("word")
plt.ylabel("count")
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='vertical')

plt.show()

# %%
stopwords=set(STOPWORDS)
wc=WordCloud(background_color='ivory', stopwords=stopwords, width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file("8장_data/riss_bigdata_wordCloud.jpg")

# %%
del word_count['big']
del word_count['data']

# %%
stopwords=set(STOPWORDS)
wc=WordCloud(background_color='ivory', stopwords=stopwords, width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()
